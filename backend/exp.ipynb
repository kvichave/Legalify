# %%
name="kunal\\vichave"
name.split("\\")[0]
# Out:
# 'kunal'

# %%
import pymupdf # previously known as fitz

doc = pymupdf.open(r"C:\Users\DNFH3173\Desktop\Legalify\temp\master_agreement.pdf")
for i, page in enumerate(doc):
    # Extract page content as HTML
    html_content = page.get_text("html")

    # Save each page to a separate file
    with open(f"page-{i}.html", "w", encoding="utf-8") as f:
        f.write(html_content)
doc.close()

# %%
import pymupdf4llm
import markdown

# Extract to Markdown
md_text = pymupdf4llm.to_markdown(r"C:\Users\DNFH3173\Desktop\Legalify\temp\invoice.pdf")
# Convert to HTML
html_content = markdown.markdown(md_text)

# %%
with open(f"page.md", "w", encoding="utf-8") as f:
        f.write(html_content)

# %%
# !pip install langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached langchain_core-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...

# %%
# !pip install dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# ...
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Using cached dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# ...
#
#    ---------------------------------------- 0/2 [python-dotenv]
#    ---------------------------------------- 2/2 [dotenv]
#
# ...

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(
    model="DeepSeek-V3.2",
    base_url="https://agentic-p.openai.azure.com/openai/v1",
    api_key=os.getenv("AZURE_MODEL"),
    temperature=0,
)

# %%
llm.invoke([{"role": "user", "content": "What is the capital of France?"}])
# Out:
# AIMessage(content='The capital of France is **Paris**.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 11, 'total_tokens': 20, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0, 'reasoning_tokens': 0}, 'model_provider': 'openai', 'model_name': 'deepseek-v3.2', 'system_fingerprint': None, 'id': 'a5bb3fea102244ffb1a685227bb97d09', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019db47a-d94b-7ad2-ab68-dfd48e7bcce6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 9, 'total_tokens': 20, 'input_token_details': {}, 'output_token_details': {}})

# %%
from langchain_core.messages import HumanMessage,AIMessage

# %%
temp=({'messages': [HumanMessage(content='Context from legal documents:\n        Company Name: ABC Solutions Address: 123 Main Street, City, State, ZIP Phone: (123) 456 -7890 Email: info@abcsolutions.com Invoice Number: 001 Date: October 27, 2023 Due Date: November 10, 2023 Bill To: John Doe 456 Elm Street City, State, ZIP **Description Quantity Unit Price Total** Web Design Services 10 hours $50 $500 Hosting Fee 1 month $20 $20 Domain Registration 1 year $10 $10 Subtotal: $530 Tax (10%): $53 Total Due: $583 Payment Terms: Please make the payment by the due date. Thank you for your business!\n\n- 421203 Maharashtra State : IN-MH State Code : MAHARASHTRA Place of Supply : Billed From Flipkart India Private Limited Warehouse Building Nos. WE-II, Renaissance Integrated Industrial Area, Village Vashere, Bhiwandi , Thane , Mumbai , Maharashtra, Thane, Maharashtra, 421302 , Maharashtra, IN-MH, IN - 421302 27AABCF8078M1Z1 GSTIN : AABCF8078M PAN : : INTRA Nature of transaction : Service Nature Of SupplyBill of Supply Details : FAAC826010576269 Bill of Supply Number : 25-03-2026 Bill of Supply Date : OD337110332308037100 Order Number Bill of Supply Particulars SAC Qty Gross AmountTaxable ValueSGST CGST Total GT Charges 996511 CGST 0.0 % SGST 0.0 %1.0 ₹510.00 ₹510.00 ₹0.00 ₹0.00 ₹510.00 Total 1.0 ₹510.00 ₹510.00 ₹0.00 ₹0.00 ₹510.00 DETAILS OF GOODS TRANSPORTED BY GTA SUPPLIER Description of GoodsQty Gross Weight of ConsignmentValue of goods MOTOROLA 139.7 cm (55 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with 5.0 OS, 50 W speaker, 120Hz Game accelerator, and Dolby Atmos (1)1.0 9000.0 grams 28489.02 of 2Signature / Digital Signature: Is the supply subject to reverse charge: No Person Liable to pay tax: GTA i.e. Flipkart India Private Limited Saidham warehousing building DE, Opp Place of Origin : Vaishnav devi Mandir, at village Dohale Post Padgha,Taluk bhiwandi , Dist Thane- 421101, MAHARASHTRA, IN-MH, India- 421101 Yuvraj Herole Destination : A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli, Maharashtra, IN-MH, IN- 421203 MH04KU1219 Registration No. of Goods Carriage: (More than 1 goods carriage may be involved in transportation of goods to the shipping address. The Registration Number mentioned above pertains to the vehicle used at the stage of commencement of transport) Flipkart India Private Limited (on behalf Consignor details: of Yuvraj Herole ) Yuvraj Herole Consignee details: I/we have taken registration under the CGST Act, 2017 and have exercised the option to pay tax on services of GTA in relation to transport of goods supplied by us from the Financial Year 2025-26 under forward charge and have not reverted to reverse charge mechanism E.& O.E.;E. & O.E. page 1 of 1 *Keep this invoice and manufacturer box for warranty purposes.Ship To Yuvraj Herole A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli. Thane 421203 Maharashtra Phone: xxxxxxxxxx Bill To Yuvraj Herole A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli. Thane 421203 Maharashtra Phone: xxxxxxxxxx Order ID: OD337110332308037100 26-03-2026 Order Date: 26-03-2026 Invoice Date: AABCJ9421C PAN:Invoice Number # EAAAAB015859935Tax Invoice Sold By: Jeeves consumer services Private Limited , Ship-from Address: L-169, 13th Cross, 5th Main,, Sector - 6, HSR Layout,, BANGALORE , KARNATAKA, 560102, IN-KA GSTIN - 29AABCJ9421C1ZP Total items: 1 Product Title Qty Gross Amount ₹Discounts /Coupons ₹Taxable Value ₹IGST ₹Total ₹ TVs FSN: SRVFH73RMTXY3JZX HSN/SAC: 998734Motorola Installation and Demo 18.0 % IGST:1 1000.00 -1000.00 0.00 0.00 0.00 Total 1 1000.00 -1000.00 0.00 0.00 1000.00 Grand Total ₹ 1000.00 Jeeves consumer services\n\nof ConsignmentValue of goods MOTOROLA 139.7 cm (55 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with 5.0 OS, 50 W speaker, 120Hz Game accelerator, and Dolby Atmos (1)1.0 9000.0 grams 28489.02 of 2Signature / Digital Signature: Is the supply subject to reverse charge: No Person Liable to pay tax: GTA i.e. Flipkart India Private Limited Saidham warehousing building DE, Opp Place of Origin : Vaishnav devi Mandir, at village Dohale Post Padgha,Taluk bhiwandi , Dist Thane- 421101, MAHARASHTRA, IN-MH, India- 421101 Yuvraj Herole Destination : A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli, Maharashtra, IN-MH, IN- 421203 MH04KU1219 Registration No. of Goods Carriage: (More than 1 goods carriage may be involved in transportation of goods to the shipping address. The Registration Number mentioned above pertains to the vehicle used at the stage of commencement of transport) Flipkart India Private Limited (on behalf Consignor details: of Yuvraj Herole ) Yuvraj Herole Consignee details: I/we have taken registration under the CGST Act, 2017 and have exercised the option to pay tax on services of GTA in relation to transport of goods supplied by us from the Financial Year 2025-26 under forward charge and have not reverted to reverse charge mechanism E.& O.E.;E. & O.E. page 1 of 1 *Keep this invoice and manufacturer box for warranty purposes.Ship To Yuvraj Herole A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli. Thane 421203 Maharashtra Phone: xxxxxxxxxx Bill To Yuvraj Herole A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli. Thane 421203 Maharashtra Phone: xxxxxxxxxx Order ID: OD337110332308037100 26-03-2026 Order Date: 26-03-2026 Invoice Date: AABCJ9421C PAN:Invoice Number # EAAAAB015859935Tax Invoice Sold By: Jeeves consumer services Private Limited , Ship-from Address: L-169, 13th Cross, 5th Main,, Sector - 6, HSR Layout,, BANGALORE , KARNATAKA, 560102, IN-KA GSTIN - 29AABCJ9421C1ZP Total items: 1 Product Title Qty Gross Amount ₹Discounts /Coupons ₹Taxable Value ₹IGST ₹Total ₹ TVs FSN: SRVFH73RMTXY3JZX HSN/SAC: 998734Motorola Installation and Demo 18.0 % IGST:1 1000.00 -1000.00 0.00 0.00 0.00 Total 1 1000.00 -1000.00 0.00 0.00 1000.00 Grand Total ₹ 1000.00 Jeeves consumer services Private Limited Signature Authorized Signatory Regd. office: , L-169, 13th Cross, 5th Main,, Sector - 6, HSR Layout,, BANGALORE, KARNATAKA - 560102 Jeeves consumer services Private Limited Contact Flipkart: 044-45614700 | 044-67415800 || www.flipkart.com/helpcentre\n\n400059, IN-MH , GSTIN - 27AABCO4794P1ZN Total items: 1 Product Title Qty Gross Amount ₹Discount ₹ Taxable Value ₹SGST /UTGST ₹CGST ₹Total ₹ Digital Combo FSN: DLCHEWD2PJAYFMVF HSN/SAC: 998599Accidental & Liquid Damage for 3 Years on TV 9.0 % SGST/UTGST: 9.0 % CGST:1 1299.00 0.00 1100.84 99.08 99.08 1299.00 Total 1 1299.00 0.00 1100.84 99.08 99.08 1299.00 Grand Total ₹ 1299.00 Signature This is a computer generated invoice. No signature required. Regd. office: , OneAssist Consumer Solutions Pvt. Ltd, , 707-709, Acme Plaza, Opp Big Cinemas, Andheri Kurla Road, Andheri (E), MUMBAI, OneAssist Consumer Solutions Pvt. Ltd. MAHARASHTRA - 400059 Contact Flipkart: 1800 208 9898 || www.flipkart.com/helpcentreE. & O.E. page 1 of 1 *Keep this invoice and manufacturer box for warranty purposes.Ship To Yuvraj Herole A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli. Thane 421203 Maharashtra Phone: xxxxxxxxxx Bill To Yuvraj Herole A104, RX-4 Maruti Darshan CHS, Milap Nagar, MIDC Nivasi Vibhag, Dombivali East, Sudama Nagar, Nanasaheb Dharmadhikari Marg, Dombivli East, Dombivli. Thane 421203 Maharashtra Phone: xxxxxxxxxx Order ID: OD337110332308037100 23-03-2026 Order Date: 24-03-2026 Invoice Date: AAECB9200C PAN: U32109DL2012PTC231885 CIN: Invoice Number # LIAC3A6260000037Tax Invoice Sold By: Bathla Teletech Pvt Ltd , Ship-from Address: Saidham warehousing building DE, Opp Vaishnav devi Mandir, at village Dohale Post Padgha,Taluk bhiwandi , Dist Thane- 421101, Bhiwandi , MAHARASHTRA, India - 421101, IN-MH GSTIN - 27AAECB9200C2Z4 Total items: 1 Product Title Qty
elm Street City, State, ZIP **Description Quantity Unit Price Total** Web Design Services 10 hours $50 $500 Hosting Fee 1 month $20 $20 Domain Registration 1 year $10 $10 Subtotal: $530 Tax (10%): $53 Total Due: $583 Payment Terms: Please make the payment by the due date. Thank you for your business!\n\n        User Query: what is the total cost?\n\n        Answer:"" ', additional_kwargs={}, response_metadata={}, id='4e129508-b543-407e-8720-4c7bc4c804d5'), AIMessage(content='Based on the context provided, there are multiple invoices with different total costs:\n\n1. **ABC Solutions Invoice**: Total due is $583 (from the first invoice for web design services, hosting, and domain registration).\n\n2. **Flipkart-related invoices**: There are several invoices for a TV purchase and related services:\n   - TV purchase: ₹28,489.00\n   - Installation and Demo: ₹1,000.00 (though shows ₹0.00 tax and total)\n   - Accidental & Liquid Damage protection: ₹1,299.00\n   - Protect Promise Fee: ₹155.00\n   - Credit Card Fee: ₹3.00\n   - Another Credit Card Fee: ₹88.00\n   - GT Charges: ₹510.00\n\n**Total cost for the Flipkart purchase**: ₹28,489 + ₹1,000 + ₹1,299 + ₹155 + ₹3 + ₹88 + ₹510 = **₹31,544.00**\n\nSince you asked for "the total cost" without specifying which invoice, I need to clarify: Are you asking about the ABC Solutions invoice total ($583) or the total cost of the Flipkart TV purchase (₹31,544)?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 253, 'prompt_tokens': 12459, 'total_tokens': 12712, 'completion_tokens_details': None, 'prompt_tokens_details': None, 'audio_prompt_tokens': 0, 'reasoning_tokens': 0}, 'model_provider': 'openai', 'model_name': 'deepseek-v3.2', 'system_fingerprint': None, 'id': '0e8dfb7b94694d3286f0c9d4036820c8', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019db491-9acf-75c1-b6d1-031bc8d90cc7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12459, 'output_tokens': 253, 'total_tokens': 12712, 'input_token_details': {}, 'output_token_details': {}})]},)

# %%
temp[0]["messages"]
# Out:
# [HumanMessage(content='Context from legal documents:\n        Company Name: ABC Solutions Address: 123 Main Street, City, State, ZIP Phone: (123) 456 -7890 Email: info@abcsolutions.com Invoice Number: 001 Date: October 27, 2023 Due Date: November 10, 2023 Bill To: John Doe 456 Elm Street City, State, ZIP **Description Quantity Unit Price Total** Web Design Services 10 hours $50 $500 Hosting Fee 1 month $20 $20 Domain Registration 1 year $10 $10 Subtotal: $530 Tax (10%): $53 Total Due: $583 Payment Terms: Please make the payment by the due date. Thank you for your business!\n\n- 421203 Maharashtra State : IN-MH State Code : MAHARASHTRA Place of Supply : Billed From Flipkart India Private Limited Warehouse Building Nos. WE-II, Renaissance Integrated Industrial Area, Village Vashere, Bhiwandi , Thane , Mumbai , Maharashtra, Thane, Maharashtra, 421302 , Maharashtra, IN-MH, IN - 421302 27AABCF8078M1Z1 GSTIN : AABCF8078M PAN : : INTRA Nature of transaction : Service Nature Of SupplyBill of
# ...

# %%
import uuid

def generate_uid():
    """Generate a unique identifier (UUID)"""
    return str(uuid.uuid4())

# Example usage
uid = generate_uid()
print(uid)
# Out:
# 1bd7528d-c89a-4a6b-b641-af29f58bac4c

# %%
str(uuid.uuid4())
# Out:
# '07509595-2d56-4ffb-8ba4-5cd656c05923'
